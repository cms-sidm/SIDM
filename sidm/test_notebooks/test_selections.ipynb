# %%
# python
import os
import sys
import importlib
# columnar analysis
from coffea.nanoevents import NanoAODSchema
from coffea import processor
# local
sidm_path = str(os.getcwd()).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import sidm_processor, utilities
# always reload local modules to pick up changes during development
importlib.reload(sidm_processor)
importlib.reload(utilities)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()

# %%
selections_menu = utilities.load_yaml(f"{sidm_path}/sidm/configs/selections.yaml")

# %%
for ch in selections_menu:
    print(ch)
    sel = selections_menu[ch]
    print("  obj cuts")
    if "obj_cuts" in sel:
        for obj, cuts in sel["obj_cuts"].items():
            print(f"    {obj}: {utilities.flatten(cuts)}")
    else:
        print("    None")
    print("  post-LJ obj cuts")
    if "postLj_obj_cuts" in sel:
        for obj, cuts in sel["postLj_obj_cuts"].items():
            print(f"    {obj}: {utilities.flatten(cuts)}")
    else:
        print("    None")
    print("  event cuts")
    if "evt_cuts" in sel:
        print(f"    {utilities.flatten(sel['evt_cuts'])}")
    else:
        print("    None")
    print()
    print()
# Out:
# ljsource_cuts
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# gen_level_cuts
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# trigger
#   obj cuts
#     None
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers']
#
#
# pv_cuts
#   obj cuts
#     None
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter']
#
#
# baseNoLjNoLjsource
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljDisplacementIso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'displaced']
#     egm_ljs: ['egm_lj_iso < 0.2', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# 4mu
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', '4mu']
#
#
# 2mu2e
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', '2mu2e']
#
#
# base_sr
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'displaced']
#     egm_ljs: ['egm_lj_iso < 0.2', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', 'LJ-LJ dPhi > 2']
#
#
# 4mu_sr
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'displaced']
#     egm_ljs: ['egm_lj_iso < 0.2', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', 'LJ-LJ dPhi > 2', '4mu']
#
#
# 2mu2e_sr
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'displaced']
#     egm_ljs: ['egm_lj_iso < 0.2', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', 'LJ-LJ dPhi > 2', '2mu2e']
#
#
# ljsource_cuts_chargeCC
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all + charge']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# ljsource_cuts_barrel
#   obj cuts
#     electrons: ['pT > 10 GeV', 'barrel', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', 'barrel']
#     photons: ['pT > 20 GeV', 'barrel', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', 'barrel', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# ljsource_cuts_endcap
#   obj cuts
#     electrons: ['pT > 10 GeV', 'endcap', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', 'endcap']
#     photons: ['pT > 20 GeV', 'endcap', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', 'endcap', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# gen_leptons_final
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter']
#
#
# gen_leptons_born
#   obj cuts
#     genMus: ['status 23']
#     genEs: ['status 23']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter']
#
#
# baseNoLjNoLjsource_noTrigger
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter']
#
#
# baseNoLj_noTrigger
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter']
#
#
# baseNoLj_egLj
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     egm_ljs: ['egLj']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# 2mu_2LJ_CC
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['|eta| < 2.4', 'pT > 30 GeV', '2muLj']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# 2mu_2LJ_CC_charge
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all + charge']
#   post-LJ obj cuts
#     ljs: ['|eta| < 2.4', 'pT > 30 GeV', '2muLj']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# 2LJ_CC
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['|eta| < 2.4', 'pT > 30 GeV']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# 2LJ_CC_charge
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all + charge']
#   post-LJ obj cuts
#     ljs: ['|eta| < 2.4', 'pT > 30 GeV']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# base_ljObjCut_pixelHits_as_ljSource
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4', 'trkNumPixelHits <= 2']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_pixelHits_as_lj_cut
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'pf_pixelhits <= 2']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_0e_lostHits
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'looseID', 'missing_hits == 0']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_1e_lostHits
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'looseID', 'missing_hits == 1']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_ljIso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_ljIso_2lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso_2lj_barrel
#   obj cuts
#     electrons: ['pT > 10 GeV', 'barrel', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', 'barrel']
#     photons: ['pT > 20 GeV', 'barrel', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', 'barrel', 'displaced ID', 'all']
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', 'barrel']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso_2lj_endcap
#   obj cuts
#     electrons: ['pT > 10 GeV', 'endcap', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', 'endcap']
#     photons: ['pT > 20 GeV', 'endcap', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', 'endcap', 'displaced ID', 'all']
#     genMus: ['status 1']
#     genEs: ['status 1']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', 'endcap']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso_2pf
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'pfMuLj', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_ljIso_2pf_2lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'pfMuLj', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso_1dsa_2lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', '1dsaMuLj', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso_1pf_1dsa_2lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'pf_dsa_muLj', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso_2dsa
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'dsaMuLj', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_ljIso0p1_2dsa_2lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'dsaMuLj', 'mu_lj_iso < 0.1']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=1 egm_ljs', '>=1 mu_ljs']
#
#
# base_ljObjCut_ljIso0p1_dxy
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL', 'dxy >= 0.05']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4', 'dxy >= 0.008']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'lj_iso < 0.1']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_ljObjCut_ljIso0p2
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'lj_iso < 0.2']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# matchedLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'dR(LJ, A) < 0.2']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', '>=2 matched As']
#
#
# 4mu_matchedLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'dR(LJ, A) < 0.2']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', '>=2 matched As', '4mu']
#
#
# 2mu2e_matchedLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'dR(LJ, A) < 0.2']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs', '>=2 matched As', '2mu2e']
#
#
# matched_leptons
#   obj cuts
#     electrons: ['dR(e, A) < 0.5']
#     muons: ['dR(mu, A) < 0.5']
#     photons: ['dR(gm, A) < 0.5']
#     dsaMuons: ['dR(mu, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# matched_ljsource_leptons
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL', 'dR(e, A) < 0.5']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4', 'dR(mu, A) < 0.5']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025', 'dR(gm, A) < 0.5']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all', 'dR(mu, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     None
#
#
# baseNoLjNoLjsource_matchedLeptons
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['dR(e, A) < 0.5']
#     muons: ['dR(mu, A) < 0.5']
#     photons: ['dR(gm, A) < 0.5']
#     dsaMuons: ['dR(mu, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_matchedLeptons
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL', 'dR(e, A) < 0.5']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4', 'dR(mu, A) < 0.5']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025', 'dR(gm, A) < 0.5']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all', 'dR(mu, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# base_egmLj_eLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#     egm_ljs: ['eLj']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# base_egmLj_gLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#     egm_ljs: ['gLj']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# base_egmLj_egLj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#     egm_ljs: ['egLj']
#   event cuts
#     ['pass triggers', 'PV filter', '>=2 LJs']
#
#
# baseNoLj_promptA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs: ['lxy < 10 cm']
#     genAs_toE: ['lxy < 10 cm']
#     genAs_toMu: ['lxy < 10 cm']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_displacedA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs: ['10 cm <= lxy < 100 cm']
#     genAs_toE: ['10 cm <= lxy < 100 cm']
#     genAs_toMu: ['10 cm <= lxy < 100 cm']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_veryDisplacedA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs: ['lxy >= 100 cm']
#     genAs_toE: ['lxy >= 100 cm']
#     genAs_toMu: ['lxy >= 100 cm']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_noLoose
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'PV filter']
#
#
# baseNoLj_noPixelSeed
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', 'eta', 'looseID']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'PV filter']
#
#
# baseNoLj_noLoose_barrel
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', 'barrel']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'looseID', 'barrel']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', 'barrel', 'looseID']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel_sieie
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel', 'barrel_sieie']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', 'barrel', 'barrel_sieie']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel_hoe
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel', 'barrel_hoe']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', 'barrel', 'barrel_hoe']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel_iso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel', 'barrel_iso']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel_eInvMinusPInv
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel', 'barrel_eInvMinusPInv']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel_lostHists
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel', 'lostHits']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_barrel_convVeto
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'barrel', 'convVeto']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'looseID']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap_sieie
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'endcap_sieie']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap_hoe
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'endcap_hoe']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap_iso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'endcap_iso']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap_eInvMinusPInv
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'endcap_eInvMinusPInv']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap_lostHists
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'lostHits']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_endcap_convVeto
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', 'endcap', 'convVeto']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# barrelE
#   obj cuts
#     electrons: ['|eta| < 1.479']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# barrelE_matched
#   obj cuts
#     electrons: ['|eta| < 1.479', 'dR(e, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# endcapE
#   obj cuts
#     electrons: ['1.479 < |eta| < 2.4']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# endcapE_matched
#   obj cuts
#     electrons: ['1.479 < |eta| < 2.4', 'dR(e, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# looseBarrelE
#   obj cuts
#     electrons: ['|eta| < 1.479', 'pT > 10 GeV', 'looseID']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# looseBarrelE_matched
#   obj cuts
#     electrons: ['|eta| < 1.479', 'pT > 10 GeV', 'looseID', 'dR(e, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# looseEndcapE
#   obj cuts
#     electrons: ['1.479 < |eta| < 2.4', 'pT > 10 GeV', 'looseID']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# looseEndcapE_matched
#   obj cuts
#     electrons: ['1.479 < |eta| < 2.4', 'pT > 10 GeV', 'looseID', 'dR(e, A) < 0.5']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['Keep all evts']
#
#
# baseNoLj_A_ee_matched_lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_highPtA_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE']
#
#
# baseNoLj_A_ee_matched_lj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_lj_highPT_lowLxyA_iso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_lj_highPT_lowLxyA_iso_disp
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['egm_lj_iso < 0.2', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_highPtA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE']
#
#
# baseNoLj_A_ee_matched_lj_highPT
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['lxy <= 150 cm']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE']
#
#
# baseNoLj_A_ee_matched_lj_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_lj_lowLxyA_iso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_lj_lowLxyA_iso_disp
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['egm_lj_iso < 0.2', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_elj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['eLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_1elj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['1eLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_2elj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['2eLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_glj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['gLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_1glj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['1gLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_2glj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['2gLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_ee_matched_eglj_highPT_lowLxyA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toE: ['pT > 30 GeV', 'lxy <= 150 cm']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toE: ['dR(A, LJ) < 0.4']
#     egm_ljs: ['egLj']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toE_matched_egmLj']
#
#
# baseNoLj_A_mumu_highPtA
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu']
#
#
# baseNoLj_A_mumu
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu']
#
#
# baseNoLj_A_mumu_matched_lj
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_lj_iso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_lj_iso_disp
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_lj_highPT
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_lj_highPT_iso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_lj_highPT_iso_disp
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'mu_lj_iso < 0.1', 'displaced']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_pflj_highPT
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'pfMuLj', 'mu_lj_iso < 0.1']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_dsalj_highPT
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'dsaMuLj', 'mu_lj_iso < 0.1']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_pfDsalj_highPT
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#     mu_ljs: ['Mu >= 2', 'pf_dsa_muLj', 'mu_lj_iso < 0.1']
#   event cuts
#     ['pass triggers', 'PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_highPtA_noPfMatch
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter', 'genAs_toMu']
#
#
# baseNoLj_A_mumu_matched_lj_highPT_noPfMatch
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID']
#     genAs_toMu: ['pT > 30 GeV']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'pT < 150 GeV']
#     mu_ljs: ['Mu >= 2']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_noPfMatch
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID']
#   post-LJ obj cuts
#     None
#   event cuts
#     ['PV filter', 'genAs_toMu']
#
#
# baseNoLj_A_mumu_matched_lj_noPfMatch
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'pT < 150 GeV']
#     mu_ljs: ['Mu >= 2']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_A_mumu_matched_lj_noPfMatch_highLjPt
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4', 'pT < 650 GeV']
#     mu_ljs: ['Mu >= 2']
#     genAs_toMu: ['dR(A, LJ) < 0.4']
#   event cuts
#     ['PV filter', 'genAs_toMu_matched_muLj']
#
#
# baseNoLj_No_Muon_Constraint
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Even_Muon_Charge
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Only_One_Muon
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu == 1']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Only_Two_Muon
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu == 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Only_Three_Muon
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu == 3']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Four_Ormore_Muon
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 4']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Two_Ormore_Muon
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Even_Muon_Charge_Displacement
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'displaced']
#     egm_ljs: ['displaced']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Only_Two_Muon_Displacement
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu == 2', 'displaced']
#     egm_ljs: ['displaced']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Two_Ormore_Muon_Displacement
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'displaced']
#     egm_ljs: ['displaced']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Two_Ormore_Muon_Displacement_EgmIso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'displaced']
#     egm_ljs: ['displaced', 'egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Two_Ormore_Muon_Displacement_MuIso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'displaced', 'mu_lj_iso < 0.1']
#     egm_ljs: ['displaced']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# baseNoLj_Two_Ormore_Muon_Displacement_EgmIso_MuIso
#   obj cuts
#     genMus: ['status 1']
#     genEs: ['status 1']
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2', 'displaced', 'mu_lj_iso < 0.1']
#     egm_ljs: ['displaced', 'egm_lj_iso < 0.2']
#   event cuts
#     ['pass triggers', 'PV filter']
#
#
# data_control_region_1Lj
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', 'pass flags', '= 1 LJs']
#
#
# data_control_region_1Lj_cosmic_veto
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all', '|dxy| <= 40', '|dz| <= 60']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', 'pass flags', '= 1 LJs', 'all cos_alpha(dsa, dsa) > -0.9']
#
#
# data_control_region_1muLj
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', 'pass flags', '= 1 LJs', '= 1 muLJs']
#
#
# data_control_region_1muLj_cosmic_veto
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all', '|dxy| <= 40', '|dz| <= 60']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#     mu_ljs: ['Mu >= 2']
#   event cuts
#     ['pass triggers', 'PV filter', 'pass flags', '= 1 LJs', '= 1 muLJs', 'all cos_alpha(dsa, dsa) > -0.9']
#
#
# data_control_region_1egmLj
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'pass flags', '= 1 LJs', '= 1 egmLJs']
#
#
# data_control_region_1egmLj_cosmic_veto
#   obj cuts
#     electrons: ['pT > 10 GeV', '|eta| < 2.4', 'MVANonIsoWPL']
#     muons: ['looseID', 'pT > 5 GeV', '|eta| < 2.4']
#     photons: ['pT > 20 GeV', '|eta| < 2.5', 'Custom Cutbased', 'pixelSeed', 'Photon DR Veto 0p025']
#     dsaMuons: ['pT > 10 GeV', '|eta| < 2.4', 'displaced ID', 'all', '|dxy| <= 40', '|dz| <= 60']
#   post-LJ obj cuts
#     ljs: ['pT > 30 GeV', '|eta| < 2.4']
#   event cuts
#     ['pass triggers', 'PV filter', 'pass flags', '= 1 LJs', '= 1 egmLJs', 'all cos_alpha(dsa, dsa) > -0.9']
