# %%
# python
import sys
import os
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema
import awkward as ak
from dask.distributed import Client, performance_report
# local

sidm_path = str(os.getcwd()).split("/sidm")[0]
# sidm_path = str(sys.path[0]).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import utilities, sidm_processor, scaleout, cutflow
from sidm.tools import llpnanoaodschema
# always reload local modules to pick up changes during development
importlib.reload(utilities)
importlib.reload(sidm_processor)
importlib.reload(scaleout)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
from tqdm.notebook import tqdm
import coffea.util
import numpy as np
import mplhep as hep
import yaml
from sidm.tools.utilities import get_cut_yield, print_CR_yield, extract_cutflow_yields, plot_cutflow_panels

# %%
yaml_file_path = '../../configs/ntuples/signal_2mu2e_v10.yaml'
# Open and read the YAML file
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)
signals_2mu2e_all = list(data["llpNanoAOD_v2"]["samples"].keys())

yaml_file_path = '../../configs/ntuples/signal_4mu_v10.yaml'
# Open and read the YAML file
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)
signals_4mu_all = list(data["llpNanoAOD_v2"]["samples"].keys())

# %%
samples_bkg = [
    "TTJets",
    "QCD_Pt15To20",
    "QCD_Pt20To30",
    "QCD_Pt30To50",
    "QCD_Pt50To80",
    "QCD_Pt80To120", 
    "QCD_Pt120To170",
    "QCD_Pt170To300", 
    "QCD_Pt300To470",
    "QCD_Pt470To600", 
    "QCD_Pt600To800", 
    "QCD_Pt800To1000",
    "QCD_Pt1000", 
    "DYJetsToMuMu_M10to50",
    "DYJetsToMuMu_M50", 
    "WW",
    "WZ",
    "ZZ",
]

# %%
#First check if there is already an out dictionary
try:
    out
    print("The _out_ dictionary already exists; will use what is saved in memory if possible")
except NameError:
    print("WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead")
    out = {}

#For each sample, try to use the data in memory if possible; if not try to load the file
#If those both fail, then raise an error and skip it
for sample in signals_2mu2e_all:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
    else:
        print(f"Loading file for sample {sample}")
        filename = "signal_2mu2e.coffea"
        try: 
            output = coffea.util.load("data_control_region_1muLj_1egmLj_cosmic_veto/"+filename)
            print("Successfully opened file")        
            out[sample] = output["out"][sample]
            # out[sample] = output["out"][sample.removesuffix("_part1")]
        except Exception:
            out[sample] = output[sample]
            # print("**** ERROR! File not found. Check the file name, or run the processor again and save the output to a pickle file using coffea.util.save")
# Out:
# WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead
# Loading file for sample 2Mu2E_100GeV_0p25GeV_0p02mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_0p25GeV_0p2mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_0p25GeV_2p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_0p25GeV_10p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_0p25GeV_20p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_1p2GeV_0p096mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_1p2GeV_0p96mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_1p2GeV_9p6mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_1p2GeV_48p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_1p2GeV_96p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_5p0GeV_0p4mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_5p0GeV_4p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_5p0GeV_40p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_5p0GeV_200mm
# Successfully opened file
# Loading file for sample 2Mu2E_100GeV_5p0GeV_400mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_0p25GeV_0p013mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_0p25GeV_0p13mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_0p25GeV_1p3mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_0p25GeV_6p7mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_0p25GeV_13p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_1p2GeV_0p064mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_1p2GeV_0p64mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_1p2GeV_6p4mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_1p2GeV_32p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_1p2GeV_64p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_5p0GeV_0p27mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_5p0GeV_2p7mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_5p0GeV_27p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_5p0GeV_130p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_150GeV_5p0GeV_270p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_0p25GeV_0p01mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_0p25GeV_0p1mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_0p25GeV_1p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_0p25GeV_5p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_0p25GeV_10p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_1p2GeV_0p048mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_1p2GeV_0p48mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_1p2GeV_4p8mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_1p2GeV_24p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_1p2GeV_48p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_5p0GeV_0p2mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_5p0GeV_2p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_5p0GeV_20p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_5p0GeV_100p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_200GeV_5p0GeV_200p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_0p25GeV_0p004mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_0p25GeV_0p04mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_0p25GeV_0p4mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_0p25GeV_2p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_0p25GeV_4p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_1p2GeV_0p019mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_1p2GeV_0p19mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_1p2GeV_1p9mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_1p2GeV_9p6mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_1p2GeV_19p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_5p0GeV_0p08mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_5p0GeV_0p8mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_5p0GeV_8p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_5p0GeV_40p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_500GeV_5p0GeV_80p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_0p25GeV_0p0025mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_0p25GeV_0p025mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_0p25GeV_0p25mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_0p25GeV_1p2mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_0p25GeV_2p5mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_1p2GeV_0p012mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_1p2GeV_0p12mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_1p2GeV_1p2mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_1p2GeV_6p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_1p2GeV_12p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_5p0GeV_0p05mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_5p0GeV_0p5mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_5p0GeV_5p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_5p0GeV_25p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_800GeV_5p0GeV_50p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_0p25GeV_0p002mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_0p25GeV_0p02mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_0p25GeV_0p2mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_0p25GeV_1p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_0p25GeV_2p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_1p2GeV_0p0096mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_1p2GeV_0p096mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_1p2GeV_0p96mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_1p2GeV_4p8mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_1p2GeV_9p6mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_5p0GeV_0p04mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_5p0GeV_0p4mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_5p0GeV_4p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_5p0GeV_20p0mm
# Successfully opened file
# Loading file for sample 2Mu2E_1000GeV_5p0GeV_40p0mm
# Successfully opened file

# %%
#First check if there is already an out dictionary
try:
    out
    print("The _out_ dictionary already exists; will use what is saved in memory if possible")
except NameError:
    print("WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead")
    out = {}
    
#For each sample, try to use the data in memory if possible; if not try to load the file
#If those both fail, then raise an error and skip it
for sample in signals_4mu_all:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
    else:
        print(f"Loading file for sample {sample}")
        filename = "signal_4mu.coffea"
        try: 
            output = coffea.util.load("data_control_region_1muLj_1egmLj_cosmic_veto/"+filename)
            print("Successfully opened file")        
            out[sample] = output["out"][sample]
            # out[sample] = output["out"][sample.removesuffix("_part1")]
        except Exception:
            out[sample] = output[sample]
            # print("**** ERROR! File not found. Check the file name, or run the processor again and save the output to a pickle file using coffea.util.save")
# Out:
# The _out_ dictionary already exists; will use what is saved in memory if possible
# Loading file for sample 4Mu_100GeV_0p25GeV_0p02mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_0p25GeV_0p2mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_0p25GeV_2p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_0p25GeV_10p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_0p25GeV_20p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_1p2GeV_0p096mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_1p2GeV_0p96mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_1p2GeV_9p6mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_1p2GeV_48p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_1p2GeV_96p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_5p0GeV_0p4mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_5p0GeV_4p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_5p0GeV_40p0mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_5p0GeV_200mm
# Successfully opened file
# Loading file for sample 4Mu_100GeV_5p0GeV_400mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_0p25GeV_0p013mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_0p25GeV_0p13mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_0p25GeV_1p3mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_0p25GeV_6p7mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_0p25GeV_13p0mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_1p2GeV_0p064mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_1p2GeV_0p64mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_1p2GeV_6p4mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_1p2GeV_32p0mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_1p2GeV_64p0mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_5p0GeV_0p27mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_5p0GeV_2p7mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_5p0GeV_27p0mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_5p0GeV_130p0mm
# Successfully opened file
# Loading file for sample 4Mu_150GeV_5p0GeV_270p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_0p25GeV_0p01mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_0p25GeV_0p1mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_0p25GeV_1p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_0p25GeV_5p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_0p25GeV_10p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_1p2GeV_0p048mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_1p2GeV_0p48mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_1p2GeV_4p8mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_1p2GeV_24p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_1p2GeV_48p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_5p0GeV_0p2mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_5p0GeV_2p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_5p0GeV_20p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_5p0GeV_100p0mm
# Successfully opened file
# Loading file for sample 4Mu_200GeV_5p0GeV_200p0mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_0p25GeV_0p004mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_0p25GeV_0p04mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_0p25GeV_0p4mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_0p25GeV_2p0mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_0p25GeV_4p0mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_1p2GeV_0p019mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_1p2GeV_0p19mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_1p2GeV_1p9mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_1p2GeV_9p6mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_1p2GeV_19p0mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_5p0GeV_0p08mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_5p0GeV_0p8mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_5p0GeV_8p0mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_5p0GeV_40p0mm
# Successfully opened file
# Loading file for sample 4Mu_500GeV_5p0GeV_80p0mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_0p25GeV_0p0025mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_0p25GeV_0p025mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_0p25GeV_0p25mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_0p25GeV_1p2mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_0p25GeV_2p5mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_1p2GeV_0p012mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_1p2GeV_0p12mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_1p2GeV_1p2mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_1p2GeV_6p0mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_1p2GeV_12p0mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_5p0GeV_0p05mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_5p0GeV_0p5mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_5p0GeV_5p0mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_5p0GeV_25p0mm
# Successfully opened file
# Loading file for sample 4Mu_800GeV_5p0GeV_50p0mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_0p25GeV_0p002mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_0p25GeV_0p02mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_0p25GeV_0p2mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_0p25GeV_1p0mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_0p25GeV_2p0mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_1p2GeV_0p0096mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_1p2GeV_0p096mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_1p2GeV_0p96mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_1p2GeV_4p8mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_1p2GeV_9p6mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_5p0GeV_0p04mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_5p0GeV_0p4mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_5p0GeV_4p0mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_5p0GeV_20p0mm
# Successfully opened file
# Loading file for sample 4Mu_1000GeV_5p0GeV_40p0mm
# Successfully opened file

# %%
#First check if there is already an out dictionary
try:
    out
    print("The _out_ dictionary already exists; will use what is saved in memory if possible")
except NameError:
    print("WARNING! No processor output stored in the kernel's memory. Will try to load pickled coffea file for each sample instead")
    out = {}

#For each sample, try to use the data in memory if possible; if not try to load the file
#If those both fail, then raise an error and skip it
for sample in samples_bkg:
    if sample in out:
        print(f"{sample} already found in memory; not loading file")
    else:
        print(f"Loading file for sample {sample}")
        filename = sample + ".coffea"
        try: 
            output = coffea.util.load("data_control_region_1muLj_1egmLj_cosmic_veto/"+filename)
            print("Successfully opened file")        
            out[sample] = output["out"][sample]
            # out[sample] = output["out"][sample.removesuffix("_part1")]
        except Exception:
            out[sample] = output[sample]
            # print("**** ERROR! File not found. Check the file name, or run the processor again and save the output to a pickle file using coffea.util.save")
# Out:
# The _out_ dictionary already exists; will use what is saved in memory if possible
# Loading file for sample TTJets
# Successfully opened file
# Loading file for sample QCD_Pt15To20
# Successfully opened file
# Loading file for sample QCD_Pt20To30
# Successfully opened file
# Loading file for sample QCD_Pt30To50
# Successfully opened file
# Loading file for sample QCD_Pt50To80
# Successfully opened file
# Loading file for sample QCD_Pt80To120
# Successfully opened file
# Loading file for sample QCD_Pt120To170
# Successfully opened file
# Loading file for sample QCD_Pt170To300
# Successfully opened file
# Loading file for sample QCD_Pt300To470
# Successfully opened file
# Loading file for sample QCD_Pt470To600
# Successfully opened file
# Loading file for sample QCD_Pt600To800
# Successfully opened file
# Loading file for sample QCD_Pt800To1000
# Successfully opened file
# Loading file for sample QCD_Pt1000
# Successfully opened file
# Loading file for sample DYJetsToMuMu_M10to50
# Successfully opened file
# Loading file for sample DYJetsToMuMu_M50
# Successfully opened file
# Loading file for sample WW
# Successfully opened file
# Loading file for sample WZ
# Successfully opened file
# Loading file for sample ZZ
# Successfully opened file

# %%
channels = [
    "data_control_region_1muLj_1egmLj_cosmic_veto",
]

# %%
result = print_CR_yield(
    out,
    signals_2mu2e_all,
    samples_bkg,
    cut_name="all cos_alpha(dsa, dsa) > -0.9",
    channel=channels[0],
    weighted=True,
    cumulative=True,
)
# Out:
# === Signal yields ===
# 2Mu2E_100GeV_0p25GeV_0p02mm         : 6.298045
# 2Mu2E_100GeV_0p25GeV_0p2mm          : 5.964344
# 2Mu2E_100GeV_0p25GeV_2p0mm          : 4.830301
# 2Mu2E_100GeV_0p25GeV_10p0mm         : 2.053457
# QCD_Pt50To80                        : 13020.767858
# QCD_Pt80To120                       : 24888.957096
# QCD_Pt120To170                      : 18333.017115
# QCD_Pt170To300                      : 13058.550234
# QCD_Pt300To470                      : 2674.086234
# QCD_Pt470To600                      : 380.823424
# QCD_Pt600To800                      : 151.219026
# QCD_Pt800To1000                     : 33.546505
# QCD_Pt1000                          : 13.778796
# DYJetsToMuMu_M10to50                : 1238.075080
# DYJetsToMuMu_M50                    : 0.551942
# WW                                  : 6.444932
# WZ                                  : 8.268430
# ZZ                                  : 6.493569
#
# === Totals ===
# S = 957.693831
# B = 82204.645004
# S/(S+B) = 1.151596e-02

# %%
result = print_CR_yield(
    out,
    signals_4mu_all,
    samples_bkg,
    cut_name="all cos_alpha(dsa, dsa) > -0.9",
    channel=channels[0],
    weighted=True,
    cumulative=True,
)
# Out:
# === Signal yields ===
# 4Mu_100GeV_0p25GeV_0p02mm           : 0.010857
# 4Mu_100GeV_0p25GeV_0p2mm            : 0.011659
# 4Mu_100GeV_0p25GeV_2p0mm            : 0.015956
# 4Mu_100GeV_0p25GeV_10p0mm           : 0.015581
# 4Mu_100GeV_0p25GeV_20p0mm           : 0.012784
# 4Mu_100GeV_1p2GeV_0p096mm           : 0.008242
# 4Mu_100GeV_1p2GeV_0p96mm            : 0.010280
# 4Mu_100GeV_1p2GeV_9p6mm             : 0.006470
# 4Mu_100GeV_1p2GeV_48p0mm            : 0.016368
# 4Mu_100GeV_1p2GeV_96p0mm            : 0.020693
# 4Mu_100GeV_5p0GeV_0p4mm             : 0.002423
# 4Mu_100GeV_5p0GeV_4p0mm             : 0.010407
# 4Mu_100GeV_5p0GeV_40p0mm            : 0.020954
# 4Mu_100GeV_5p0GeV_200mm             : 0.010210
# 4Mu_100GeV_5p0GeV_400mm             : 0.011390
# 4Mu_150GeV_0p25GeV_0p013mm          : 0.006310
# 4Mu_150GeV_0p25GeV_0p13mm           : 0.010023
# 4Mu_150GeV_0p25GeV_1p3mm            : 0.018078
# 4Mu_150GeV_0p25GeV_6p7mm            : 0.027533
# 4Mu_150GeV_0p25GeV_13p0mm           : 0.037958
# 4Mu_150GeV_1p2GeV_0p064mm           : 0.006684
# 4Mu_150GeV_1p2GeV_0p64mm            : 0.003944
# 4Mu_150GeV_1p2GeV_6p4mm             : 0.015188
# 4Mu_150GeV_1p2GeV_32p0mm            : 0.029530
# 4Mu_150GeV_1p2GeV_64p0mm            : 0.026138
# 4Mu_150GeV_5p0GeV_0p27mm            : 0.006178
# 4Mu_150GeV_5p0GeV_2p7mm             : 0.006689
# 4Mu_150GeV_5p0GeV_27p0mm            : 0.020352
# 4Mu_150GeV_5p0GeV_130p0mm           : 0.030289
# 4Mu_150GeV_5p0GeV_270p0mm           : 0.022087
# 4Mu_200GeV_0p25GeV_0p01mm           : 0.005582
# 4Mu_200GeV_0p25GeV_0p1mm            : 0.004500
# 4Mu_200GeV_0p25GeV_1p0mm            : 0.018514
# 4Mu_200GeV_0p25GeV_5p0mm            : 0.051508
# 4Mu_1000GeV_1p2GeV_0p096mm          : 0.010204
# 4Mu_1000GeV_1p2GeV_0p96mm           : 0.096379
# 4Mu_1000GeV_1p2GeV_4p8mm            : 0.112145
# 4Mu_1000GeV_1p2GeV_9p6mm            : 0.088983
# 4Mu_1000GeV_5p0GeV_0p04mm           : 0.009788
# 4Mu_1000GeV_5p0GeV_0p4mm            : 0.010087
# 4Mu_1000GeV_5p0GeV_4p0mm            : 0.104671
# 4Mu_1000GeV_5p0GeV_20p0mm           : 0.119839
# 4Mu_1000GeV_5p0GeV_40p0mm           : 0.091144
#
# === Background yields ===
# TTJets                              : 2830.247366
# QCD_Pt15To20                        : 0.000000
# QCD_Pt20To30                        : 2884.649275
# QCD_Pt30To50                        : 2675.168121
# QCD_Pt50To80                        : 13020.767858
# QCD_Pt80To120                       : 24888.957096
# QCD_Pt120To170                      : 18333.017115
# QCD_Pt170To300                      : 13058.550234
# QCD_Pt300To470                      : 2674.086234
# QCD_Pt470To600                      : 380.823424
# QCD_Pt600To800                      : 151.219026
# QCD_Pt800To1000                     : 33.546505
# QCD_Pt1000                          : 13.778796
# DYJetsToMuMu_M10to50                : 1238.075080
# DYJetsToMuMu_M50                    : 0.551942
# WW                                  : 6.444932
# WZ                                  : 8.268430
# ZZ                                  : 6.493569
#
# === Totals ===
# S = 3.111546
# B = 82204.645004
# S/(S+B) = 3.784979e-05

# %%
group1_2mu2e = [
    "2Mu2E_100GeV_0p25GeV_0p02mm",
    "2Mu2E_100GeV_0p25GeV_20p0mm",
    "2Mu2E_100GeV_1p2GeV_0p096mm",
    "2Mu2E_100GeV_1p2GeV_96p0mm",
    "2Mu2E_100GeV_5p0GeV_0p4mm",
    "2Mu2E_100GeV_5p0GeV_400mm",
]

group2_2mu2e = [
    "2Mu2E_150GeV_0p25GeV_0p013mm",
    "2Mu2E_150GeV_0p25GeV_13p0mm",
    "2Mu2E_150GeV_1p2GeV_0p064mm",
    "2Mu2E_150GeV_1p2GeV_64p0mm",
    "2Mu2E_150GeV_5p0GeV_0p27mm",
    "2Mu2E_150GeV_5p0GeV_270p0mm",
]

group3_2mu2e = [
    "2Mu2E_200GeV_0p25GeV_0p01mm",
    "2Mu2E_200GeV_0p25GeV_10p0mm",
    "2Mu2E_200GeV_1p2GeV_0p048mm",
    "2Mu2E_200GeV_1p2GeV_48p0mm",
    "2Mu2E_200GeV_5p0GeV_0p2mm",
    "2Mu2E_200GeV_5p0GeV_200p0mm",
]

group4_2mu2e = [
    "2Mu2E_500GeV_0p25GeV_0p004mm",
    "2Mu2E_500GeV_0p25GeV_4p0mm",
    "2Mu2E_500GeV_1p2GeV_0p019mm",
    "2Mu2E_500GeV_1p2GeV_19p0mm",
    "2Mu2E_500GeV_5p0GeV_0p08mm",
    "2Mu2E_500GeV_5p0GeV_80p0mm",
]

group5_2mu2e = [
    "2Mu2E_800GeV_0p25GeV_0p0025mm",
    "2Mu2E_800GeV_0p25GeV_2p5mm",
    "2Mu2E_800GeV_1p2GeV_0p012mm",
    "2Mu2E_800GeV_1p2GeV_12p0mm",
    "2Mu2E_800GeV_5p0GeV_0p05mm",
    "2Mu2E_800GeV_5p0GeV_50p0mm",
]

group6_2mu2e = [
    "2Mu2E_1000GeV_0p25GeV_0p002mm",
    "2Mu2E_1000GeV_0p25GeV_2p0mm",
    "2Mu2E_1000GeV_1p2GeV_0p0096mm",
    "2Mu2E_1000GeV_1p2GeV_9p6mm",
    "2Mu2E_1000GeV_5p0GeV_0p04mm",
    "2Mu2E_1000GeV_5p0GeV_40p0mm",
]

# %%
group1_4mu = [
    "4Mu_100GeV_0p25GeV_0p02mm",
    "4Mu_100GeV_0p25GeV_20p0mm",
    "4Mu_100GeV_1p2GeV_0p096mm",
    "4Mu_100GeV_1p2GeV_96p0mm",
    "4Mu_100GeV_5p0GeV_0p4mm",
    "4Mu_100GeV_5p0GeV_400mm",
]

group2_4mu = [
    "4Mu_150GeV_0p25GeV_0p013mm",
    "4Mu_150GeV_0p25GeV_13p0mm",
    "4Mu_150GeV_1p2GeV_0p064mm",
    "4Mu_150GeV_1p2GeV_64p0mm",
    "4Mu_150GeV_5p0GeV_0p27mm",
    "4Mu_150GeV_5p0GeV_270p0mm",
]

group3_4mu = [
    "4Mu_200GeV_0p25GeV_0p01mm",
    "4Mu_200GeV_0p25GeV_10p0mm",
    "4Mu_200GeV_1p2GeV_0p048mm",
    "4Mu_200GeV_1p2GeV_48p0mm",
    "4Mu_200GeV_5p0GeV_0p2mm",
    "4Mu_200GeV_5p0GeV_200p0mm",
]

group4_4mu = [
    "4Mu_500GeV_0p25GeV_0p004mm",
    "4Mu_500GeV_0p25GeV_4p0mm",
    "4Mu_500GeV_1p2GeV_0p019mm",
    "4Mu_500GeV_1p2GeV_19p0mm",
    "4Mu_500GeV_5p0GeV_0p08mm",
    "4Mu_500GeV_5p0GeV_80p0mm",
]

group5_4mu = [
    "4Mu_800GeV_0p25GeV_0p0025mm",
    "4Mu_800GeV_0p25GeV_2p5mm",
    "4Mu_800GeV_1p2GeV_0p012mm",
    "4Mu_800GeV_1p2GeV_12p0mm",
    "4Mu_800GeV_5p0GeV_0p05mm",
    "4Mu_800GeV_5p0GeV_50p0mm",
]

group6_4mu = [
    "4Mu_1000GeV_0p25GeV_0p002mm",
    "4Mu_1000GeV_0p25GeV_2p0mm",
    "4Mu_1000GeV_1p2GeV_0p0096mm",
    "4Mu_1000GeV_1p2GeV_9p6mm",
    "4Mu_1000GeV_5p0GeV_0p04mm",
    "4Mu_1000GeV_5p0GeV_40p0mm",
]

# %%
QCD = [
    "QCD_Pt15To20",
    "QCD_Pt20To30",
    "QCD_Pt30To50",
    "QCD_Pt50To80",
    "QCD_Pt80To120",
    "QCD_Pt120To170",
    "QCD_Pt170To300",
    "QCD_Pt300To470",
    "QCD_Pt470To600",
    "QCD_Pt600To800",
    "QCD_Pt800To1000",
    "QCD_Pt1000",
]

DY = [
    "DYJetsToMuMu_M10to50",
    "DYJetsToMuMu_M50",
]

TT = ["TTJets"]

Diboson = [
    "WW",
    "WZ",
    "ZZ"]

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_2mu2e,
        group2_2mu2e,
        group3_2mu2e,
        group4_2mu2e,
        group5_2mu2e,
        group6_2mu2e,
    ],
    channel=channels[0],
    titles=[
        "2Mu2E 100 GeV",
        "2Mu2E 150 GeV",
        "2Mu2E 200 GeV",
        "2Mu2E 500 GeV",
        "2Mu2E 800 GeV",
        "2Mu2E 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=False,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_2mu2e,
        group2_2mu2e,
        group3_2mu2e,
        group4_2mu2e,
        group5_2mu2e,
        group6_2mu2e,
    ],
    channel=channels[0],
    titles=[
        "2Mu2E 100 GeV",
        "2Mu2E 150 GeV",
        "2Mu2E 200 GeV",
        "2Mu2E 500 GeV",
        "2Mu2E 800 GeV",
        "2Mu2E 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=True,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_4mu,
        group2_4mu,
        group3_4mu,
        group4_4mu,
        group5_4mu,
        group6_4mu,
    ],
    channel=channels[0],
    titles=[
        "4Mu 100 GeV",
        "4Mu 150 GeV",
        "4Mu 200 GeV",
        "4Mu 500 GeV",
        "4Mu 800 GeV",
        "4Mu 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=False,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        group1_4mu,
        group2_4mu,
        group3_4mu,
        group4_4mu,
        group5_4mu,
        group6_4mu,
    ],
    channel=channels[0],
    titles=[
        "4Mu 100 GeV",
        "4Mu 150 GeV",
        "4Mu 200 GeV",
        "4Mu 500 GeV",
        "4Mu 800 GeV",
        "4Mu 1000 GeV",
    ],
    unweighted=False,
    cumulative=True,
    normalize=True,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        QCD,
        DY,
        TT,
        Diboson,
    ],
    channel=channels[0],
    titles=[
        "QCD",
        "DY",
        "TT",
        "Diboson",
    ],
    unweighted=False,
    cumulative=True,
    normalize=False,
    logy=True,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)

# %%
fig, axes = plot_cutflow_panels(
    out=out,
    sample_groups=[
        QCD,
        DY,
        TT,
        Diboson,
    ],
    channel=channels[0],
    titles=[
        "QCD",
        "DY",
        "TT",
        "Diboson",
    ],
    unweighted=False,
    cumulative=True,
    normalize=True,
    logy=False,
    figsize=(36, 24),
    ncols=3,
    ncol_legend=1,
)
